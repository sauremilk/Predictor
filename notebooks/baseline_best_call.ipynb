# %%
# Zelle 1: Beispiel - trainiere das Baseline-Modell mit der Demo-Datei
# !python3 src/train_best_call_baseline.py --data data/call_states_demo.csv
